# %%
str=''
print(str)

# %%
type(str)
# Out:
# str

# %%
print(type(str))
# Out:
# <class 'str'>

# %%
str
# Out:
# ''

# %%
str='shripad'
print(str)
# Out:
# shripad

# %%
str
# Out:
# 'shripad'

# %%
str='domino's'
print(str)
# Out:
#   Cell In[7], line 1
#     str='domino's'
#                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str="domino's"
print(str)
# Out:
# domino's

# %%
print("\nthis is multiline\nthis is multiline\nthis is multiline")
# Out:
# this is multiline
# this is multiline
# this is multiline

# %%
str1="shripad"
print(str1[0])
print(str1[-1])
print(str1[:7:])
print(str1[0:])
print(str1[:])
print(str1[::-1])
# Out:
# s
# d
# shripad
# shripad
# shripad
# dapirhs

# %%
str1='shripad'
n=len(str1)
print('the length of string is:',n)
# Out:
# the length of string is: 7

# %%
'shri' in str1
# Out:
# True

# %%
index=str1.index('s')
print(index)
# Out:
# 0

# %%
str1.find('shri')
# Out:
# 0

# %%
str1.find('ri')
# Out:
# 2

# %%
str1.find('pad')
# Out:
# 4

# %%
str1.find('cad')
# Out:
# -1

# %%
#counting occurance in a string
str2='shripad '
count=str2.count('c')
count=str2.count('a')
count=str2.count(' ')
print(count)
# Out:
# 1

# %%
#ASCII value
val=ord('A')
val1=ord('a')
print(val)
print(val1)
# Out:
# 65
# 97

# %%
string="  KRISHNA is good"
str1=string.lower()
print(str1)
# Out:
#   krishna is good

# %%
str1.upper()
# Out:
# 'KRISHNA IS GOOD'

# %%
str1.capitalize()
# Out:
# 'Krishna is good'

# %%
str1.title()
# Out:
# '  Krishna Is Good'

# %%
# remove spaces from left side
str1.lstrip()
# Out:
# 'krishna is good'

# %%
#remove spaces from right side
str1.rstrip()
# Out:
# '  krishna is good'

# %%
# remove spaces from both side
str1.strip()
# Out:
# 'krishna is good'

# %%
my_string="I find python"
my_string=my_string.replace('I','We')
print(my_string)
# Out:
# We find python
