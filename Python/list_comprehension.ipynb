# %%
squares=[x**2 for x in range(1,6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
sq=[i**2 for i in range(1,11) if i%2==0]
print(sq)
# Out:
# [4, 16, 36, 64, 100]

# %%
movies = [
    "The Shawshank Redemption",
    "The Godfather",
    "The Dark Knight",
    "Inception",
    "Interstellar",
    "Parasite",
    "Pulp Fiction",
    "3 Idiots",
    "Lagaan",
    "gaare Zameen Par",
    "The Matrix",
    "gight Club",
    "Forrest Gump",
    "Avengers: Endgame",
    "Dangal",
    "PK",
    "Sholay",
    "Dilwale Dulhania Le Jayenge",
    "Zindagi Na Milegi Dobara",
    "Drishyam"
]
print(movies)
# Out:
# ['The Shawshank Redemption', 'The Godfather', 'The Dark Knight', 'Inception', 'Interstellar', 'Parasite', 'Pulp Fiction', '3 Idiots', 'Lagaan', 'gaare Zameen Par', 'The Matrix', 'gight Club', 'Forrest Gump', 'Avengers: Endgame', 'Dangal', 'PK', 'Sholay', 'Dilwale Dulhania Le Jayenge', 'Zindagi Na Milegi Dobara', 'Drishyam']

# %%
# display movies name that begins with g
movie_g=[]
for movie in movies:
    if movie.startswith('g'):
        movie_g.append(movie)

print(movie_g)
# Out:
# ['gaare Zameen Par', 'gight Club']

# %%
#using list comprehwnsion
movie_g=[str1 for str1 in movies if str1.startswith('g')]
print(movie_g)
# Out:
# ['gaare Zameen Par', 'gight Club']

# %%
input_list=['wood','elo','ice','apple']
ans=[word for word in input_list if word[0] in 'aeiouAEIOU']
print(ans)
# Out:
# ['elo', 'ice', 'apple']
