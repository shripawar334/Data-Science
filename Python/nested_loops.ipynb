# %%
for i in range(1,4):
    for j in range(1,4):
        print(i*j,end="\t")
    print()
# Out:
# 1	2	3
# 2	4	6
# 3	6	9

# %%
row=7
for i in range(row+1):
    for j in range(i):
        print('*',end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *

# %%
while True:
    name=input("enter your name:")
    if name=="shripad":
        print(name)
        break
# Out:
# enter your name: hari
# enter your name: ksjd
# enter your name: jfj
# enter your name: shripad
# shripad
