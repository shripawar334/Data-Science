# %%
print("hello world")
# Out:
# hello world

# %%
print("in next video")
# Out:
# in next video

# %%
print("good morning")
# Out:
# good morning

# %%
import math
m.sqrt(9)
# Out:
# 3.0

# %%
num=9
print("hello",num)
# Out:
# hello 9

# %%
import keyword
print("python keywords:-",keyword.kwlist)
# Out:
# python keywords:- ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
_Vae=9
print(_Vae)
# Out:
# 9

# %%
# returns float value
avg=101/4
print(avg)
# Out:
# 25.25

# %%
# returns flooe value
avg=101//4
print(avg)
# Out:
# 25

# %%
remainder=101%2
print(remainder)
# Out:
# 1

# %%
#2 raise to 3-> 2 x 2 x 2
print(2**3)
# Out:
# 8

# %%
age=12
if age>18:
    print("you can vote")
else:
    print("you cannot vote")
# Out:
# you cannot vote

# %%
a=90
print(a is None)
# Out:
# False

# %%
a=None
print(a is None)
# Out:
# True

# %%
# list
skills=['java','python','sql']
print("python in skills:",'python' in skills)
# Out:
# python in skills: True

# %%
skills=['java','python','sql']
print("mongodb not in skills:",'mongodb' not in skills)
# Out:
# mongodb not in skills: True

# %%
candidate={
    'name':'ravi',
    'skills':['java','python','cpp']
}
# check if candidate has python and java as a skill
if 'python' in candidate['skills'] and 'java' in candidate['skills']:
    print('yes',candidate['name'],"is eligible for the job")
else:
    print("no")
# Out:
# yes ravi is eligible for the job

# %%
a=int(input("enter a number"))
b=a//10
print(b)
# Out:
# enter a number 21
# 2

# %%
mark=9
if mark>=90:
    print("topper")
elif mark>80 and mark<90:
    print("good work")
elif mark>70 and mark<80:
    print("keep going")
elif mark>35:
    print("pass")
else:
    print("better luck next time","fail")
# Out:
# better luck next time fail

# %%
while True:
    a=int(input("enter a number"))
    if a%2==0:
        print(a,"is even")
    else:
        print(a,"is odd")
# Out:
# enter a number 4
# 4 is even
# enter a number 6
# 6 is even
# enter a number 5
# 5 is odd
# enter a number 2
# 2 is even
# enter a number 1
# 1 is odd
