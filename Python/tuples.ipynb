# %%
my_tuple=(1,2,3,4)
print(my_tuple)
# Out:
# (1, 2, 3, 4)

# %%
type(my_tuple)
# Out:
# tuple

# %%
# access elements
my_tuple[0]
# Out:
# 1

# %%
for i in my_tuple:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
my_tuple[-2]
# Out:
# 3

# %%
my_tuple[-1]
# Out:
# 4

# %%
#slicing
my_tuple[0:4]
# Out:
# (1, 2, 3, 4)

# %%
# tuple cannot be changed
my_tuple=(1,2,3,4)
my_tuple[0]=90
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 my_tuple=(1,2,3,4)
# ----> 2 my_tuple[0]=90
#
# TypeError: 'tuple' object does not support item assignment

# %%
# converting list to tuple
list1=[1,2,3,4,5]
my_tuple=tuple(list1)
print(my_tuple)
# Out:
# (1, 2, 3, 4, 5)

# %%
# finding a length of tuple
my_tuple=(1,2,3,4)
n=len(my_tuple)
print(n)
# Out:
# 4

# %%
1 in my_tuple
# Out:
# True

# %%
my_tuple.index(3)
# Out:
# 2

# %%
max(my_tuple)
# Out:
# 4

# %%
min(my_tuple)
# Out:
# 1

# %%
my_tuple.count(2)
# Out:
# 1

# %%
my_tuple.count(22)
# Out:
# 0

# %%
#concating the 2 tuple
tuple1=('h','e','l','l','o')

# %%
tuple1
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
tuple2=('h','e','l','l','o')

# %%
new_tuple=tuple1+tuple2

# %%
new_tuple
# Out:
# ('h', 'e', 'l', 'l', 'o', 'h', 'e', 'l', 'l', 'o')

# %%
#creates a separate copy -> not changes original one
my_tuple=(5,8,2,4,2)
sorted_tuple=sorted(my_tuple)
sorted_tuple
# Out:
# [2, 2, 4, 5, 8]

# %%
type(sorted_tuple)
# Out:
# list

# %%
my_tuple
# Out:
# (5, 8, 2, 4, 2)

# %%
sum(my_tuple)
# Out:
# 21
