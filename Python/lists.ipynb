# %%
my_list=[1,2,3,4,5]
print(my_list[0])
print(my_list[-1])
print(my_list)
# Out:
# 1
# 5
# [1, 2, 3, 4, 5]

# %%
my_list.append(90)

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 90]

# %%
my_list.pop()
# Out:
# 90

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
mixed_list=[1,'a','shripad',[1,2,3],90,True,9.8]
print(mixed_list)
# Out:
# [1, 'a', 'shripad', [1, 2, 3], 90, True, 9.8]

# %%
for i in mixed_list:
    print(i)
# Out:
# 1
# a
# shripad
# [1, 2, 3]
# 90
# True
# 9.8

# %%
type(mixed_list[0])
# Out:
# int

# %%
for i in mixed_list:
    type(i)

# %%
type(mixed_list)
# Out:
# list

# %%
mixed_list[0:3]
# Out:
# [1, 'a', 'shripad']

# %%
mixed_list=[1,'a','shripad',[1,2,3],90,True,9.8]

# %%
mixed_list[3][0]
# Out:
# 1

# %%
mixed_list[3][1]
# Out:
# 2

# %%
print(len(mixed_list))
# Out:
# 7

# %%
list1=[1,2,3,4,5]
max_element=max(list1)
min_element=min(list1)
print(max_element)
print(min_element)
# Out:
# 5
# 1

# %%
list1=[1,2,3,4,5]
list1.index(5)
# Out:
# 4

# %%
list1.count(2)
# Out:
# 1

# %%
list2=[4,7,2,5,3]
list2.sort()

# %%
print(list2)
# Out:
# [2, 3, 4, 5, 7]

# %%
sum(list2)
# Out:
# 21

# %%
2 in list2
# Out:
# True

# %%
90 in list2
# Out:
# False

# %%
# delete element at index 4-> del removes element at index i
list2=[4,7,2,5,3]
del list2[0]
print(list2)
# Out:
# [7, 2, 5, 3]

# %%
# delete element 2-> remove() function directly removes the element
list2=[4,7,2,5,3]
list2.remove(2)
print(list2)
# Out:
# [4, 7, 5, 3]

# %%
# working with sublists nested-list
car_models=[
    ["maruti alto","huindai 100","tata tiago"], #hatchbacks
    ["honda city","verna","skoda"],             #sedans
    ["nexon","mhindra","creta"]                 #suv's
]

# %%
sedans=car_models[1]
print(sedans)
# Out:
# ['honda city', 'verna', 'skoda']
