# %%
#dictionary representing inventory
inventory={
    "rise":50,
    "dal":90,
    "wheat":40
}
for item,quantity in inventory.items():
    print(f"-{item}:{quantity} kg")
# Out:
# -rise:50 kg
# -dal:90 kg
# -wheat:40 kg

# %%
#add a new item in dictionary
inventory["salt"]=15

# %%
print(inventory)
# Out:
# {'rise': 50, 'dal': 90, 'wheat': 40, 'salt': 15}

# %%
inventory["salt"]+=15

# %%
print(inventory)
# Out:
# {'rise': 50, 'dal': 90, 'wheat': 40, 'salt': 30}

# %%
for item,quantity in inventory.items():
    print(f"-{item}:{quantity} kg")
# Out:
# -rise:50 kg
# -dal:90 kg
# -wheat:40 kg
# -salt:30 kg

# %%
print(inventory["rise"])
# Out:
# 50
