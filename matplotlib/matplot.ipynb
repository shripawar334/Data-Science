# %% [markdown]
# # Matplotlib-Data Visualization in Python

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Figure and Axes

# %%
#setting parameters
fig,ax=plt.subplots()
ax.set_title('basic figure and axis')
ax.set_xlabel('days')
ax.set_ylabel('total patients')
plt.show()

# %% [markdown]
# # Line Plot

# %%
## Line Plot: Patient Recovery Trends
### Problem Statement:
# A hospital tracks the recovery rate of patients over several months.
# We visualize the trend using a line plot.

import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
recovery_rate = [65, 70, 60, 78, 80, 85]

plt.plot(months, recovery_rate, marker='o', linestyle='-', color='b', label="Recovery Rate")

plt.xlabel("Months")
plt.ylabel("Recovery Percentage")
plt.title("Patient Recovery Trends")
plt.legend()
plt.show()

# %% [markdown]
# # Bar Plot

# %%
import matplotlib.pyplot as plt

medicines = ["Paracetamol", "Antibiotics", "Painkillers", "Insulin", "Antacids"]
demand = [500, 700, 450, 300, 650]

plt.bar(medicines, demand, color=['red', 'blue', 'green', 'purple', 'orange'])

plt.xlabel("Medicine Type")
plt.ylabel("Units Sold")
plt.title("Medicine Demand Analysis")
plt.show()

# %% [markdown]
# # Pie chart

# %%
import matplotlib.pyplot as plt

diseases = ["Diabetes", "Hypertension", "Heart Disease", "Asthma", "Others"]
percentages = [30, 25, 15, 10, 20]
colors = ["blue", "red", "green", "purple", "orange"]

plt.pie(percentages, labels=diseases, autopct='%1.1f%%', colors=colors)

plt.title("Disease Distribution in City")
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt

time_spent = [10, 15, 20, 25, 30, 35, 40]
diagnosis_accuracy = [60, 65, 70, 75, 80, 85, 90]

plt.scatter(time_spent, diagnosis_accuracy, color='red')

plt.xlabel("Time Spent by Doctor (minutes)")
plt.ylabel("Diagnosis Accuracy (%)")

plt.title("Doctor-Patient Interaction Time vs. Diagnosis Accuracy")
plt.show()

# %% [markdown]
# # Histogram

# %%
import numpy as np
import matplotlib.pyplot as plt

ages = np.random.randint(10, 80, 100)
print(ages)

plt.hist(ages, bins=10, color='blue', edgecolor='black')

plt.xlabel("Age Groups")
plt.ylabel("Number of Patients")
plt.title("Age Distribution of Patients")
plt.show()
# Out:
# [38 68 39 73 16 23 56 42 45 63 48 16 13 74 67 67 20 23 34 42 71 55 28 21
#  39 77 75 24 23 68 23 17 49 72 41 42 36 43 75 60 16 28 67 33 15 48 58 24
#  65 13 24 74 12 23 32 58 26 34 77 76 25 72 68 66 42 18 74 52 32 31 17 65
#  60 13 72 59 67 78 69 12 60 18 73 36 71 58 15 27 49 77 71 21 64 73 63 43
#  60 43 33 18]

# %% [markdown]
# # Word Cloud

# %%
# first time install karna padta hai
# !pip install wordcloud

from wordcloud import WordCloud
import matplotlib.pyplot as plt

symptoms_text = "fever cough cold headache nausea fatigue pain weakness fever cough cold fever cough fatigue"

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(symptoms_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Common Symptoms Analysis")
plt.show()
